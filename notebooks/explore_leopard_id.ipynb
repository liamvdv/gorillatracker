# %%
import os 
import json
from pathlib import Path

# %%
cropped_images_path = Path("/workspaces/gorillatracker/compressed/test")
annotation_path = Path("/workspaces/gorillatracker/video_data/external-datasets/LeopardID2022/leopard.coco/annotations/instances_train2022.json")
image_path = Path("/workspaces/gorillatracker/video_data/external-datasets/LeopardID2022/leopard.coco/images/train2022")

# %%
def load_json(path: Path) -> dict:
    with open(path, "r") as f:
        data = json.load(f)
    return data

annotation_dict = load_json(annotation_path)
print("Given number of images: ", len(annotation_dict["images"]))
print("Given number of annotations: ", len(annotation_dict["annotations"]))
image_files = [file for file in image_path.glob("*.jpg") if not file.name.startswith("._")]
print("Actual number of images: ", len(image_files))
print("Actual number of cropped images: ", len(list(cropped_images_path.glob("*.png"))))
# Out:
# Given number of images:  6795
# Given number of annotations:  6825
# Actual number of images:  5848
# Actual number of cropped images:  5857

# %%
# Check for image_ids that come up more than once in annotations and print the name of the annotation
image_id_dict = {}
for annotation in annotation_dict["annotations"]:
    image_id = annotation["image_id"]
    if image_id in image_id_dict:
        image_id_dict[image_id].append(annotation)
    else:
        image_id_dict[image_id] = [annotation]
for image_id, annotations in image_id_dict.items():
    if len(annotations) > 1:
        print("Image ID: ", image_id)
        # print the names of the annotations
        print("Annotations: ")
        for annotation in annotations:
            print(annotation["name"])
        print("\n")
    else:
        continue
# Out:
# Image ID:  1089
# Annotations:
# e9ffb750-5aa3-48e8-9390-3dfa1c2ae629
# ____
#
#
# Image ID:  1090
# Annotations:
# e9ffb750-5aa3-48e8-9390-3dfa1c2ae629
# ____
#
#
# Image ID:  1467
# Annotations:
# 18ffc687-a6fc-4f53-b226-72eaf7f66ccc
# ____
#
#
# Image ID:  1603
# Annotations:
# 18ffc687-a6fc-4f53-b226-72eaf7f66ccc
# ____
#
#
# Image ID:  1803
# Annotations:
# b3cadf4e-6dc5-4d1a-bc0e-adc6805d9329
# ____
#
#
# Image ID:  1807
# Annotations:
# b3cadf4e-6dc5-4d1a-bc0e-adc6805d9329
# ____
#
#
# Image ID:  2135
# Annotations:
# 9ec659d2-2183-4f55-8882-1fe87e13d5f4
# ____
#
#
# Image ID:  2456
# Annotations:
# c7fa3bc1-65ee-4028-86a7-a64b841d5dba
# fc628bad-d8ce-4915-9cf1-29835d930e7c
#
#
# Image ID:  2457
# Annotations:
# fc628bad-d8ce-4915-9cf1-29835d930e7c
# c7fa3bc1-65ee-4028-86a7-a64b841d5dba
#
#
# Image ID:  2514
# Annotations:
# f830c415-8659-45ca-8426-ab5346ea4c60
# ____
#
#
# Image ID:  2631
# Annotations:
# 0f38564b-babb-43bd-b8e1-3f653ec442bb
# ...
